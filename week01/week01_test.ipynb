# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowonhyeok/ai-programming-2026/blob/main/week01/week01_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01주차 연습

# %%
print('이름:', '조원혁')
print('학과:', '정보컴퓨터공학부 인공지능전공')

print('기대:', '뒤 두 줄의 밑줄 자리가 본인 이름과 학과로 바뀌어 출력됩니다.')

# %%
# 공개 저장소 복제 (# 을 지우고 실행)
# !git clone https://github.com/octocat/Hello-World.git

print("기대: Cloning into 'Hello-World'... 로 시작하는 복제 진행 메시지가 출력됩니다")
# Out:
# Cloning into 'Hello-World'...
# remote: Enumerating objects: 13, done.
# remote: Total 13 (delta 0), reused 0 (delta 0), pack-reused 13 (from 1)
# Receiving objects: 100% (13/13), done.
# 기대: Cloning into 'Hello-World'... 로 시작하는 복제 진행 메시지가 출력됩니다

# %%
# %cd Hello-World
# !ls

print("기대: /content/Hello-World 로 이동한 뒤 README 파일 이름이 출력됩니다")
# Out:
# /content/Hello-World
# README
# 기대: /content/Hello-World 로 이동한 뒤 README 파일 이름이 출력됩니다

# %%
# !ls

print("기대: 세션 재시작 전에는 위 셀과 같은 목록, 재시작 뒤에는 작업 폴더가 /content 로 돌아가 Hello-World 폴더가 /content 의 다른 항목과 함께 출력됩니다")
# Out:
# README
# 기대: 세션 재시작 전에는 위 셀과 같은 목록, 재시작 뒤에는 작업 폴더가 /content 로 돌아가 Hello-World 폴더가 /content 의 다른 항목과 함께 출력됩니다
